# %%
#Author Suruj Kalita Date:10/15/2022 

import numpy as np; #NumPy is the fundamental package for scientific computing in Python.
import pandas as pd; #Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.
import ast 
import nltk

# %%
movie = pd.read_csv('movies_metadata.csv' , low_memory=False) #whole columns will be read in first good practice so that panda could read the properly the metadata set
credits = pd.read_csv('credits.csv' , low_memory=False)
keywords = pd.read_csv('keywords.csv' , low_memory=False)

# %%
movie.head(1) # head() function get the first element of an array switch the variable according to choice
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
#credits.head(1)['cast'].values #under credits database cast under cast values

# %%
credits.head(1) # we will be needing cast crew and id here id is the primary key
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew   id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  862

# %%
credits.shape # rows 45476 column 3
# Out:
# (45476, 3)

# %%
movie.shape # rows 90942 column 26
# Out:
# (45466, 24)

# %%
movie = pd.concat([movie,credits]) #we have merge the two dataframes  #remember merge will not work on metadata set.

# %%
movie.shape # rows 136418 , 26 merging the rows of both dataframes  column are same
# Out:
# (90942, 26)

# %%
movie.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90942 entries, 0 to 45475
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     90942 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
#
#types of dtypes --> primary , userdefined , user-defined  
#primary ->  integer character floating point double floating point void
#userdefined -> class structure Union Enum Typedef
#derived->  function array pointer Reference
#

# %%
#design the websites
#  genres
#  homepage
#  id
#  imdb_id
#  overview
#  runtime
#  cast
#  title
#  release_date

movie[['genres' , 'homepage' , 'id' , 'imdb_id' , 'overview' , 'runtime' , 'cast' , 'title' , 'release_date']] #creating the dataframes of the websites what we want
# Out:
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45471                                                NaN
# 45472                                                NaN
# 45473                                                NaN
# 45474                                                NaN
# 45475                                                NaN
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# ...

# %%
movie.duplicated().sum()  #54 duplicate rows --have to make 0
# Out:
# 54

# %%
movie.iloc[0]  #Python iloc() function enables us to select a particular cell of the dataset, that is, it helps us select a value that belongs to a particular row or column from a set of values of a data frame or dataset.
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                            30000000
# genres                   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                              http://toystory.disney.com/toy-story
# id                                                                     862
# imdb_id                                                          tt0114709
# original_language                                                       en
# original_title                                                   Toy Story
# overview                 Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.946943
# poster_path                               /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %%
movie.iloc[0].genres
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
# we have to make    Animation    Comedy    Family

# %%
# making a helper function 
def convert(obj):  # it will get string so to convert it to we use obj we use ast module
    L = []  
    for i in ast.literal_eval((obj)):
        L.append(i['name'])
    return L

# %%
# now we have to convert string of list to list
#import ast  ast is python module .
#ast.literal_eval("[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]")

# %%
#movie['genres'].apply(convert)   #data = ast.literal_eval(str(webhook_data)) # this fixes the issue
genres = ast.literal_eval(str("[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"))

# %%
print(type(movie)) # movie is a list . --> structured data
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(genres))  #---> list --- > structred data
# Out:
# <class 'list'>

# %%
newdf = movie

# %%
print(type(newdf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english') #training the dataframes to 5000 lowering the vector count for better prediction

# %%
#CountVectorizer is a great tool provided by the scikit-learn library in Python. It is used to transform a given text into a vector on the basis of the frequency (count) of each word that occurs in the entire text. This is helpful when we have multiple such texts, and we wish to convert each word in each text into vectors (for using in further text analysis).

# %%
print(type(cv)) #. Class is a set of object which shares common characteristics/ behavior and common properties/ attributes.
# Out:
# <class 'sklearn.feature_extraction.text.CountVectorizer'>

# %%
cv = np.array([5000,9])  # 5000 column and 9 rows

# %%
vector = cv

# %%
vector[0]  # 5000 values lowering the frame
# Out:
# 5000

# %%
#lets convert --- lets convert the data frame vector --stemming for better pridiction of the strings

# %%
from nltk.stem.porter import PorterStemmer #Porter Stemmer algorithm Stemming is the process of reducing a word to its stem that affixes to suffixes and prefixes or to the roots of words lemma.
ps = PorterStemmer()

# %%
def stem(movie):
    y = []
    
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
movie
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45471    NaN                                                NaN       NaN
# 45472    NaN                                                NaN       NaN
# 45473    NaN                                                NaN       NaN
# 45474    NaN                                                NaN       NaN
# 45475    NaN                                                NaN       NaN
#
#                                                   genres  \
# ...

# %%
# now we are ready 5000 movie and 5000 vectors 
# now we have to calculate the distance between the movies more the distance lesser the similarity 
# we are going to calculate the cosine value of the vectors

# %%
# from sklearn.metrics.pairwise import cosine_similarity -- since the data is 1Dimesnsions -- we doesnt-need it

# %%
def recommend(movie):  #helper functions if you dont do still its ok .. cause the data is already  in listed form 
    return

# %%
import pickle #the pickle module implements binary protocols for serializing and de-serializing a Python object structure.

# %%
#----and the project is done---- #showing some problem in recommendation---- ##HEROKU DEPLOYMENT
